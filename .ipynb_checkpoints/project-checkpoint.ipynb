# %%
import pandas
import matplotlib.pyplot as plt
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import r2_score, mean_squared_error
import warnings; warnings.simplefilter('ignore')

# %%
#Read dataset 
features = pandas.read_csv("data/train_features.csv", parse_dates=[3])
labels = pandas.read_csv("data/train_labels.csv")

# %%
#Data Analysis

#Plot Number of cases Vs WeekOfTheYear 
cityDataSetLabeled = {"sj":[],"iq":[]}
cityDataSetLabeled["sj"] = labels[labels["city"] == "sj"]
cityDataSetLabeled["iq"] = labels[labels["city"] == "iq"]

for city in cityDataSetLabeled:
    count_year = cityDataSetLabeled[city].set_index(['year', 'weekofyear'])
    count_year.plot(figsize = (15,5))
    plt.xlabel("Year, Week of Year")
    plt.ylabel("Number of Cases")

# %%
#Data Cleaning

#segregate data based on city and use forward filling for handling missing values
data_train = {"sj":[],"iq":[]}

data_train["sj"] = features[features["city"] == "sj"].fillna(method = 'ffill')
data_train["iq"] = features[features["city"] == "iq"].fillna(method = 'ffill')

for city in data_train:
    data_train[city].set_index('week_start_date')
    data_train[city].drop(['city', 'year'], axis = 1, inplace = True)

# %%
#ARIMA

source = []

for entry in cityDataSetLabeled["sj"]["total_cases"]:
    source.append(int(entry))
    
N = len(source)
nowcasts = []
start = int(0.7*N)
for k in range(start, N-1):
    model = ARIMA(source[:k], order=(2,1,2))
    fitted = model.fit(start_ar_lags=5)

    nowcasts.append(int(fitted.forecast()[0][0]))

offset = N - start - len(nowcasts)

plt.rcParams["figure.figsize"]=(15,5)
fig, ax1 = plt.subplots()

ax1.plot(list(range(0, N-1)), source[offset:], color='k')
ax1.plot(list(range(start, N-1)), nowcasts, color='b')

ax1.axvline(x=start)

# %%
#ZOOMING IN to see clearly
plt.rcParams["figure.figsize"]=(15,5)
fig, ax1 = plt.subplots()
ax1.plot(list(range(start, N-1)), source[start+offset:], color='k')
ax1.plot(list(range(start, N-1)), nowcasts, color='b')

ax1.axvline(x=start)

# print('r^2:', r2_score(source[(start+offset):], nowcasts))
# print('MSE:', mean_squared_error(source[(start+offset):], nowcasts) )
# print(source[(start+offset):], nowcasts)
# Out:
# r^2: 0.7673285689552661
# MSE: 164.95357142857142
# [9, 3, 6, 11, 7, 7, 15, 9, 6, 6, 6, 7, 10, 8, 7, 12, 3, 2, 7, 5, 5, 7, 7, 7, 7, 10, 13, 10, 14, 11, 20, 25, 17, 18, 25, 21, 31, 32, 26, 35, 28, 37, 41, 34, 30, 39, 39, 39, 34, 30, 37, 29, 26, 15, 22, 15, 20, 14, 10, 21, 14, 14, 9, 11, 5, 6, 7, 11, 4, 3, 2, 6, 10, 7, 5, 3, 12, 13, 10, 13, 13, 8, 21, 18, 8, 7, 20, 14, 14, 7, 14, 10, 13, 27, 13, 18, 16, 16, 20, 17, 4, 15, 8, 6, 12, 15, 11, 10, 15, 17, 7, 7, 8, 9, 12, 12, 5, 4, 11, 4, 5, 7, 1, 1, 4, 2, 6, 3, 4, 10, 12, 21, 26, 21, 30, 45, 56, 75, 83, 82, 126, 119, 137, 131, 112, 82, 73, 43, 55, 55, 53, 46, 43, 29, 22, 26, 13, 17, 8, 13, 10, 17, 19, 9, 9, 9, 3, 7, 7, 0, 2, 3, 3, 1, 3, 3, 3, 7, 3, 5, 11, 5, 5, 6, 6, 4, 4, 8, 14, 12, 16, 10, 16, 18, 15, 23, 17, 33, 15, 13, 11, 14, 17, 19, 20, 12, 21, 7, 19, 10, 13, 10, 8, 21, 11, 9, 14, 14, 15, 18, 16, 12, 20, 8, 3, 13, 4, 1, 10, 8, 13, 10, 21, 18, 21, 34, 25, 34, 33, 40, 42, 36, 72, 75, 76, 92, 71, 112, 106, 101, 170, 135, 106, 68, 48, 48, 26, 33, 29, 17, 12, 13, 17, 15, 14, 15, 10, 9, 2, 6, 8, 5, 1, 2, 3, 4, 3, 1, 3, 5] [3, 5, 9, 2, 5, 13, 5, 7, 16, 8, 4, 6, 5, 7, 10, 8, 6, 13, 1, 1, 8, 4, 4, 7, 7, 6, 7, 10, 13, 9, 14, 10, 21, 26, 15, 18, 26, 20, 32, 33, 24, 36, 27, 37, 42, 32, 29, 40, 39, 38, 33, 28, 38, 27, 24, 13, 22, 14, 19, 14, 7, 23, 12, 13, 8, 10, 4, 5, 7, 11, 3, 1, 2, 6, 11, 6, 4, 2, 13, 13, 9, 13, 13, 7, 23, 18, 5, 6, 22, 14, 12, 6, 13, 10, 12, 30, 10, 18, 16, 15, 21, 16, 1, 15, 8, 4, 14, 15, 10, 9, 16, 17, 5, 6, 8, 8, 12, 11, 3, 3, 12, 2, 4, 7, 0, 0, 4, 1, 6, 2, 3, 11, 12, 22, 27, 20, 31, 48, 58, 78, 85, 81, 134, 122, 140, 133, 108, 77, 67, 39, 52, 58, 50, 47, 40, 28, 18, 27, 9, 17, 6, 12, 10, 17, 20, 6, 8, 8, 2, 7, 7, -1, 2, 3, 3, 0, 3, 3, 2, 7, 2, 4, 12, 4, 4, 6, 5, 3, 3, 8, 15, 12, 16, 9, 16, 19, 14, 24, 16, 35, 13, 10, 11, 13, 18, 18, 21, 10, 22, 5, 19, 10, 11, 11, 6, 23, 10, 8, 14, 14, 15, 18, 15, 11, 20, 7, 0, 14, 3, 0, 10, 8, 13, 10, 22, 19, 20, 36, 24, 35, 33, 40, 43, 35, 76, 78, 77, 95, 69, 116, 109, 100, 178, 136, 102, 62, 41, 45, 20, 31, 27, 14, 9, 12, 16, 15, 13, 15, 9, 8, 0, 6, 7, 4, 0, 1, 2, 4, 2, 0]
